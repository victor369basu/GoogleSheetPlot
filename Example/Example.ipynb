# %% [markdown]
# ## Install the package

# %%
# !pip install GoogleSheetPlot==0.0.1
# Out:
# Collecting GoogleSheetPlot==0.0.1
#   Using cached GoogleSheetPlot-0.0.1.tar.gz (79 kB)
# Requirement already satisfied: requests in c:\users\victor\appdata\local\programs\python\python36-32\lib\site-packages (from GoogleSheetPlot==0.0.1) (2.24.0)
# Requirement already satisfied: pandas in c:\users\victor\appdata\local\programs\python\python36-32\lib\site-packages (from GoogleSheetPlot==0.0.1) (1.0.3)
# Requirement already satisfied: matplotlib in c:\users\victor\appdata\local\programs\python\python36-32\lib\site-packages (from GoogleSheetPlot==0.0.1) (2.2.2)
# Requirement already satisfied: google-api-python-client in c:\users\victor\appdata\local\programs\python\python36-32\lib\site-packages (from GoogleSheetPlot==0.0.1) (1.12.3)
# Requirement already satisfied: google-auth-httplib2 in c:\users\victor\appdata\local\programs\python\python36-32\lib\site-packages (from GoogleSheetPlot==0.0.1) (0.0.4)
# Requirement already satisfied: google-auth-oauthlib in c:\users\victor\appdata\local\programs\python\python36-32\lib\site-packages (from GoogleSheetPlot==0.0.1) (0.4.1)
# ERROR: Could not find a version that satisfies the requirement pickle (from GoogleSheetPlot==0.0.1) (from versions: none)
# ERROR: No matching distribution found for pickle (from GoogleSheetPlot==0.0.1)
# WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# You should consider upgrading via the 'c:\users\victor\appdata\local\programs\python\python36-32\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## import GoogleSheet
# Initialize GoogleSheetPlot, by giving your SPREADSHEET_ID(access it from your google spreadsheet link from the Google Drive account), and the range of the X and Y range from your google sheet.

# %%
from GoogleSheetPlot import GoogleSheetPlot
SAMPLE_SPREADSHEET_ID = '1SrZfvr2ee54r7HR1jGtAE9zHIj_Y-UzK9ok8bdwkpqc'
SAMPLE_RANGE_NAME = 'A1:C80'

# %% [markdown]
# ## Initialize the dataFrame

# %%
gsp = GoogleSheetPlot()
df = gsp.getDataFrame(SAMPLE_SPREADSHEET_ID, SAMPLE_RANGE_NAME)
df.head()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=352832479663-0157c6o1kjbjnk1iic49ajbclolrvq4d.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A52288%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fspreadsheets.readonly&state=ejcWCnyZngMYGhrpxaBJnEytQycXSd&access_type=offline
#     timestamp average_sales offer_price
# 0  1506317777        826951        2018
# 1  1506231377        311342        6166
# 2  1506144977        537960        4268
# 3  1506058577        971972        2729
# 4  1505972177        623545        5548

# %% [markdown]
# ## Plot the graph
# give the valid column names(X and Y axis)with the type of plot you want to get.<br>
# Your plot gets saved with the format "col1_col2_category.png".

# %%
#gsp.getPlot("Column-1", "Column-2","Plot category")
gsp.getPlot("average_sales", "offer_price","line")
# Out:
# Saved Image Successfully.
